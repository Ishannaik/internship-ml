# %% [markdown]
# # HOMEWORK

# %% [markdown]
# <div class="alert alert-block alert-success"> 1. Create Histogram, Bar chart, and Pie chart for the dataset. </div>
#
# <div class="alert alert-block alert-info">Using Excel</div>
#
# # Bar chart
# ![image.png](attachment:image.png)
# # Pie Chart
# ![image-2.png](attachment:image-2.png)
# # Histogram
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <div class="alert alert-block alert-info"> Create histogram using Programming Language.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

hist = plt.xlabel('Price (INR)', fontsize=14)
hist = plt.ylabel('No of laptops at same price range', fontsize=14)
hist = plt.hist(df['Price (INR)'])

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# 2. How to calculate the range of the following Dataset? <br>
# {7, 89, 42, 5, 67, 89, 456, 789, 56}

# %%
dataset = {7, 89, 42, 5, 67, 89, 456, 789, 56}
range = max(dataset) - min(dataset)
range
# Out:
# 784

# %% [markdown]
# <div class="alert alert-block alert-success">3. Calculate Variance and Standard Deviation.</div>
#
# ![image.png](attachment:image.png)
# <div class="alert alert-block alert-info">
# Variance and Standard Deviation has been calculated by using excel inbuilt formulas</div>
#
# ![image-2.png](attachment:image-2.png)
# <div class="alert alert-block alert-info">For Standard Deviation </div>
#
# ![image-3.png](attachment:image-3.png)
# <div class="alert alert-block alert-info">For Variance </div>
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <div class="alert alert-block alert-success">4. Calculate Standard Deviation using Python Programming.

# %%
df = pd.read_excel (r"C:\Users\ishan\Desktop\dataset.xlsx")
print(df)
sed = np.std(df['Price (INR)'])

print("\nThe standard Deviation is ",sed)
# Out:
#    Manufacturer   Category  Price (INR)
# 0         Apple  Ultrabook       133969
# 1         Apple  Ultrabook        89894
# 2            HP     Gaming        57500
# 3         Apple  Ultrabook       253745
# 4         Apple  Ultrabook       180360
# 5          Acer     Gaming        40000
# 6         Apple  Ultrabook       213997
# 7         Apple  Ultrabook       115870
# 8          Asus  Ultrabook       149500
# 9           MSI     Gaming        89190
# 10         Acer   Notebook        77000
# 11           HP   Notebook        39390
# 12           HP  Ultrabook        34499
# 13        Apple   Notebook       243997
# 14         Dell  Ultrabook        49890
# 15        Apple  Ultrabook       126240
# 16          MSI     Gaming       151855
# 17        Apple  Ultrabook       132190
# 18         Dell   Notebook        74500
# 19        Apple  Ultrabook       285800
# 20       Lenovo    Netbook        49900
# 21         Dell     Gaming        97900
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">5. Implementation to show the basic Linear Regression.

# %%
from sklearn.linear_model import LinearRegression
x=np.array([1,10,20,40,50,70,80,90,120])
y=np.array([3,20,90,110,130,170,150,200,260])

# %%
linreg = LinearRegression()

# %%
x = x.reshape(-1,1)
x
# Out:
# array([[  1],
#        [ 10],
#        [ 20],
#        [ 40],
#        [ 50],
#        [ 70],
#        [ 80],
#        [ 90],
#        [120]])

# %%
linreg.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred= linreg.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred, color='red')
plt.show()
