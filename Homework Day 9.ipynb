# %% [markdown]
# # HOMEWORK

# %% [markdown]
# <div class="alert alert-block alert-success">
# Mini Project on Machine Learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

i = 1
while i == 1:
    
#Print
    print("Enter the number of the activity which you want to view \n Day 1 - Dataset \n Day 2 - Python installation/Basic Coding \n Day 3 - Greatest Number & Place of service \n Day 4 - Develop code using (Numpy, Pandas, Matplotlib) \n Day 5 - Histogram/Standard Deviation/Linear Regression \n Day 6 - Break/Continue/Standard Deviation/Linear regression model \n Day 7 - Simple linear regression model \n Day 8 - K - Means Clustering/Decision Tree Algorithm \n Press 0 to exit")
    a=int(input())
    
#Day - 1
    #SHOW THE DATASET TO THE USER
    if a == 1:
        df = pd.read_csv(r"C:\Users\ishan\Desktop\PPT\dataset3.csv")
        print(df)
        
#Day - 2
    #SHOW THE BASIC PYTHON CODE AND USE OF VARIABLES/OPERATOR
    if a == 2:
        print("\nDevelop python code to show use of variables and operator")
        print("Use of variables")
        name = ("Ishan")
        x = 5
        y = 10
        print("My name is "+name)
        print (x+y)
        print (x*y)
        print("Arithmetic Operator")
        print(2+3)
        print("Comparison Operator")
        print(2>5)
        print("Logical Operator")
        print(3<4 and 2>1)
        print("Assignment Operator")
        m=5
        m+=10
        print(m)
        print("\n")
        
#Day - 3
    if a == 3:
        n1=1
        while n1==1:
            print("Select the program\n 1 - Show the greatest number of the two values \n 2 - Place of service \n 0 - Exit")
            m1=int(input())
            if m1==1:
                #SHOW THE GREATEST NUMBER TO THE USER
                print("\nTake two int values from user and print greatest among them")
                print("This is a program to take two int values from user and print the greatest among them\n")

                number1=int(input("Enter the first number: "))
                number2=int(input("Enter the Second number: "))
        
                if number1 > number2:
                    print("\nFirst number is greater than the second number. \n\nTherefore the greatest number is: ",number1)
    
                elif number1 < number2:
                    print("\nSecond number is greater than the first number. \n\nTherefore the greatest number is: ",number2)
        
                elif number1 == number2:    
                    print("\nBoth numbers are equal. \n\nTherefore the greatest number is: ",number1)
                print("\n")
             #PLACE OF SERVICE PROGRAM   
            if m1==2:
                print("\n\n2. Ask user to enter age, sex (M or F), marital status (Y or N) and then using\n Following rules print their place of service.\n If employee is female, then she will work only in urban areas.\n If employee is a male and age is in between 20 to 40 then he may work in anywhere.\n If employee is male and age is in between 40 to 60 then he will work in urban areas only.\n And any other input of age should print “ERROR”.")
                def place(age, gender, martial_status):
    
                    if gender == "F":
                        return "urban areas"
        
                    if 20 <= age <= 40:
                        return "anywhere"
                
                    if 40 <= age <= 60:
                        return "urban areas"

                    if age < 20 or age > 60:
                        return "Error" 

                age, gender, martial_status = int(input("Age: ")), input("M/F: "), input("Y/N: ")

                print(place(age, gender, martial_status))
                print("\n")
            if m1==0:
                n1 += 1
        print("\n")
        
#Day - 4
    if a == 4:
        n1=1
        while n1==1:
            print("Select the program\n 1 - Recursive Function \n 2 - Mean Median Mode from dataset \n 3 - Matrix Multiplication \n 4 - Single Main Title for All the Subplots in Matplotlib \n 0 - Exit")
            m1=int(input())
            if m1==1:
                #RECURSIVE FUNCTION PROGRAM
                print("\n\n\n\n\n1.Create a program to show recursive function (Except factorial).")
                def fibo(n):
                    if n <= 1:
                        return n
                    else:
                        return(fibo(n-1) + fibo(n-2))  

                nterms = int(input("How many terms? "))  

                if nterms <= 0: 
                    print("Plese enter a positive integer")  
                else:  
                    print("Fibonacci sequence:")
                    for i in range(nterms):
                        print(fibo(i))
        
                #MEAN MEDIAN MODE FROM DATASET
            if m1==2:
                print("\n")
                print("2. Prepare the data and create the mean median mode for the following data. \n - Using python Programming \n")
                df = pd.read_excel (r"C:\Users\ishan\Desktop\PPT\dataset.xlsx")
                print(df)
                print("Mean of the price")
                print(df.mean(numeric_only=True))
                print("Median of the price")
                print(df.median(numeric_only=True))
                print("Mode of the Category")
                print(df['Category'].mode())
                print(df['Manufacturer'].mode())
            
                #MATRIX MULTIPLICATION
            if m1==3:
                print("\n")
                print("3.Matrix multiplication in Numpy and how to inverse a matrix using Numpy.")
                M = np.array([[5,0,0],[0,5,0],[0,0,5]])
                N = np.array([[6,0,0],[0,6,0],[0,0,6]])
                O = np.matmul(M,N)
                print(O)
                O_inverse = np.linalg.inv(O)
                print(O_inverse)
            if m1==4:
                #MAIN TITLE FOR ALL SUBPLOTS IN MATPLOT LIB
                print("\n")
                print("4.How to set a single Main Title for All the Subplots in Matplotlib.")

                x=np.linspace(0,3,100)
                y1 = x
                y2 = x**2
                y3 = x**3
                y4 = np.sqrt(x)

                plt.subplot(2,2,1)
                plt.plot(x,y1)
                plt.title('y1=x')

                plt.subplot(2,2,2)
                plt.plot(x,y2)
                plt.title('y1=x^2')

                plt.subplot(2,2,3)
                plt.plot(x,y3)
                plt.title('y1=x^3')

                plt.subplot(2,2,4)
                plt.plot(x,y4)
                plt.title('y1=sqrt(x)')

                plt.suptitle('Various Graphs',fontsize=20)
                plt.show()
                print("\n")    
            if m1==0:
                n1 += 1
        
#Day - 5
    if a == 5:
        
        n1=1
        while n1==1:
            print("Select the program\n 1 - Create Histogram \n 2 - Range of Dataset \n 3 - Standard Deviation using Python \n 4 - Basic Linear regression \n 0 - Exit")
        
            m1=int(input())
            if m1==1:
                #HISTOGRAM USING PYTHON
                print("\n")
                df = pd.read_excel (r"C:\Users\ishan\Desktop\PPT\dataset2.xlsx")
                print("Create histogram using Programming Language")
                hist = plt.xlabel('Price (INR)', fontsize=14)
                hist = plt.ylabel('No of laptops at same price range', fontsize=14)
                hist = plt.hist(df['Price (INR)'])
                plt.show()
                
            if m1==2:
                #RANGE OF DATASET
                print("\n")
                print("2. How to calculate the range of the following Dataset? \n{7, 89, 42, 5, 67, 89, 456, 789, 56}")
                dataset = {7, 89, 42, 5, 67, 89, 456, 789, 56}
                range = max(dataset) - min(dataset)
                print(range)
                
            if m1==3:
                #STANDARD DEVIATION USING PYTHON
                print("\n")
                print("Calculate Standard Deviation using Python Programming.")
                df = pd.read_excel (r"C:\Users\ishan\Desktop\PPT\dataset.xlsx")
                print(df)
                sed = np.std(df['Price (INR)'])
                print("\nThe standard Deviation is ",sed)
                
            if m1==4:
                #BASIC LINEAR REGRESSION
                print("\n")
                print("Implementation to show the basic Linear Regression.")
                x=np.array([1,10,20,40,50,70,80,90,120])
                y=np.array([3,20,90,110,130,170,150,200,260])
                linreg = LinearRegression()
                x = x.reshape(-1,1)
                print(x)
                linreg.fit(x,y)
                y_pred= linreg.predict(x)
                plt.scatter(x,y)
                plt.plot(x,y_pred, color='red')
                plt.show()
                print("\n")
            if m1==0:
                n1 += 1
        

#Day - 6
    if a == 6:
        
        n1=1
        while n1==1:
            print("Select the program\n 1 - Use of Break and Continue Statement \n 2 - Input Append and Print the List Element, Last Element, Index of the element \n 0 - Exit")
            m1=int(input())
            if m1==1:
                #SHOW USE OF BREAK AND CONTINUE STATEMENT
                print("\n")
                print("1. Develop the code where you can show the use of break and continue statement.")
        
                print("Break")
                for a in "jupyter":
                    if a == "y":
                        break
                    print(a)
                print("The end")
        
                print("Continue")
                for a in "jupyter":
                    if a == "y":
                        continue
                    print(a)
                print("The end")
        
            if m1==2:
                #PROGRAM TO INPUT APPEND AND PRINT THE LIST ELEMENT, LAST ELEMENT, INDEX OF THE ELEMENT
                print("\n")
                print("Program to input, append and print the list element. \n How do I get last element of list. \n - Find the index of an item in the list. \n")
                print("Program to input, append and print the list element")
                lst = []
                number = int(input("Enter number of elements : "))

                for h in range(0, number):
                    element = int(input())
  
                    lst.append(element)
      
                print(lst)
                print("\nHow do I get last element of list.")
                list = [1,2,3,4,5,6,7,8,9,0]
                last_element = list[-1]
                print("The last element of the list is ",last_element)
                print("\nFind the index of an item in the list.")
                print("The index of 4 is",list.index(4))
                print("\n")
                
            if m1==3:
                #LINEAR REGRESSION ON GIVEN DATASET
                print("\n\n")
                print("Build Linear regression model on following dataset.")
                waist_cm = np.array([71,89,64,74,87,93,79,81,75,72,70,66,81,78,110]).reshape((-1, 1))
                weight_kg = np.array([51,66,45,57,64,75,61,62,55,53,48,46,63,60,100])
                print(waist_cm,weight_kg)
                model = LinearRegression().fit(waist_cm, weight_kg)
                weight_kg_pred = model.predict(waist_cm)
                plt.scatter(waist_cm,weight_kg)
                plt.plot(waist_cm,weight_kg_pred, color='red')
                plt.show()
                print("And also calculate the Standard Deviation for Weight_Kg")
                print(np.std(weight_kg))
                print("\n")
            if m1==0:
                    n1 += 1

#Day - 7 
    if a == 7:
    #SIMPLE REGRESSION MODEL   
        print("\n\n\n\n\n")
        print("Create a mini activity on simple linear regression model.")
        age = np.array([7,6,11,3,14,24,5,9,18,1,4,20,16]).reshape((-1, 1))
        height_cm = np.array([123,116,143,95,165,180,110,132,182,76,103,177,178])
        print(age,height_cm)
        model = LinearRegression().fit(age, height_cm)
        height_cm_pred = model.predict(age)
        plt.scatter(age,height_cm)
        plt.plot(age,height_cm_pred, color='red')
        plt.show()
        print("\n")

#Day - 8 
    if a == 8:
        
        n1=1
        while n1==1:
            print("Select the program\n 1 - K-Means Clustering \n 2 - Decision Tree Algorithm \n 0 - Exit")
            m1=int(input())
            if m1==1:
                #K-MEANS CLUSTERING
                print("\n\n\n\n\n")

                print("Enter the Number of Samples ")
                no_samples=int(input())
                print("Enter the value of Standard Deviation")
                no_std=float(input())
                print("Enter the value of randomness you want")
                no_rand=int(input())
                print("Enter the number of Cluster Centers")
                no_clusters=int(input())
                dataset = make_blobs(n_samples=no_samples,centers=no_clusters,n_features=2,cluster_std=no_std,random_state=no_rand)
                points = dataset[0]
                kmeans = KMeans(n_clusters=no_clusters)
                kmeans.fit(points)
                plt.scatter(dataset[0][:,0], dataset[0][:,1])
                clusters = kmeans.cluster_centers_
                y_km = kmeans.fit_predict(points)
                loop1 = 0
                loop2=0
                
                for loop in range(0,no_clusters):
                    print("Select the colour for your cluster number", loop+1)
                    colour=input()
    
                    plt.scatter(points[y_km == loop1,0], points[y_km==loop1,1], s=50, color = colour)
    
                    print(loop1)
                    if loop1<=no_clusters:
                        loop1 = loop1 + 1

                for loop in range(0,no_clusters):
                    plt.scatter(clusters[loop2][0], clusters[loop2][1], marker='*',s=200, color='black')
                    if loop2<=no_clusters:
                        loop2 = loop2 + 1
                plt.show()
                
            if m1==2:
                #DECISION TREE
                print("\n\n")
                print("Develop basic code for Decision Tree Algorithm.")
                df = pd.read_csv(r"C:\Users\ishan\Desktop\PPT\salary.csv")
                print("df")
                inputs = df.drop('salary_more_than_100k', axis='columns')
                target = df['salary_more_than_100k']
                company = LabelEncoder()
                job = LabelEncoder()
                degree = LabelEncoder()
                inputs['company_label'] = company.fit_transform(inputs['company'])
                inputs['job_label'] = job.fit_transform(inputs['job'])
                inputs['degree_label'] = degree.fit_transform(inputs['degree'])
                print(inputs)
                inputs_label= inputs.drop(['company','job','degree'], axis='columns')
                model = tree.DecisionTreeClassifier()
                model.fit(inputs_label,target)
                model.score(inputs_label,target)
                print("Input the label you want to predict")
                k=input()
                l=input()
                m=input()
                prediction = model.predict([[k,l,m]])
                print(prediction)

                if prediction == 1:
                    print("The person will have salary over 100k")
                else:
                    print("The person will not have salary over 100k")
                print("\n")
            if m1==0:
                    n1 += 1
    if a == 0:
        i+=1
# Out:
# Enter the number of the activity which you want to view
#  Day 1 - Dataset
#  Day 2 - Python installation/Basic Coding
#  Day 3 - Greatest Number & Place of service
#  Day 4 - Develop code using (Numpy, Pandas, Matplotlib)
#  Day 5 - Histogram/Standard Deviation/Linear Regression
#  Day 6 - Break/Continue/Standard Deviation/Linear regression model
#  Day 7 - Simple linear regression model
#  Day 8 - K - Means Clustering/Decision Tree Algorithm
#  Press 0 to exit
# 8
# Select the program
#  1 - K-Means Clustering
#  2 - Decision Tree Algorithm
#  0 - Exit
# 1
#
#
#
#
#
#
# Enter the Number of Samples
# 1000
# Enter the value of Standard Deviation
# 1.4
# Enter the value of randomness you want
# 5000
# Enter the number of Cluster Centers
# 6
# Select the colour for your cluster number 1
# red
# 0
# Select the colour for your cluster number 2
# blue
# 1
# Select the colour for your cluster number 3
# green
# 2
# Select the colour for your cluster number 4
# yellow
# 3
# ...

# %% [markdown]
# 3##
